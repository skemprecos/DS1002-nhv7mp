# %% [markdown]
# <a href="https://colab.research.google.com/github/skemprecos/DS1002-nhv7mp/blob/main/homework/week-7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework - Week 7
#
# Complete the following blocks as specified in the directions. Run each cell to return the desired output. Save your notebook back to your GitHub repository and submit the GitHub URL for your notebook for review.
#
# Load the following dataset into pandas and perform the requested operations in code.
#
# Source: https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv

# %%
# Load pandas and the data
import pandas as pd
df = pd.read_csv('https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv')
df.head(3)
# Out:
#      duration  station_A_id  \
# 0  12 minutes            81
# 1  24 minutes             3
# 2   8 minutes            67
#
#                                       station_A_name  station_B_id  \
# 0                                 Berry St at 4th St           323
# 1       Powell St BART Station (Market St at 4th St)           118
# 2  San Francisco Caltrain Station 2  (Townsend St...            23
#
#                     station_B_name  bike_id  user_type  user_birth_year  \
# 0               Broadway at Kearny     5480          2             1959
# 1  Eureka Valley Recreation Center     5193          2             1965
# 2    The Embarcadero at Steuart St     3652          3             1993
#
#   user_gender  tire_size
# 0        Male         26
# 1        Male         27
# 2        Male         29

# %%
# show how many rows and columns are in this dataset
df.shape
# Out:
# (25760, 10)

# %%
# The first column, "duration" is seen as a string.
# Using two snippets of code, clean this column up so that
# is now an integer (int64)
df['duration'] = df['duration'].str.strip('minutes')
df['duration'] = df['duration'].astype('int')

# %%
# Now display the datatypes in the updated dataframe
df.dtypes
# Out:
# duration            int64
# station_A_id        int64
# station_A_name     object
# station_B_id        int64
# station_B_name     object
# bike_id             int64
# user_type           int64
# user_birth_year     int64
# user_gender        object
# tire_size           int64
# dtype: object

# %%
# Show the min and max values of ride durations (the shortest and longest rides)
# Hint: If 'df' is the name of your dataframe, simply specify the column name
# and then append the .min() or .max() methods.
mindf = df['duration'].min()
mindf = df['duration'].max()

# %%
# Create a new dataframe object and populate it with rides that are 60 minutes or less.
# Hint: Use the .query() method for the dataframe that we used in class.
short_rides = df.query('duration<=60')

# %%
# Now show both the min and max values of the duration column for your new dataset.
short_rides['duration'].min()
short_rides['duration'].max()
# Out:
# 60

# %%
# Using the new dataframe, update it so that is ONLY has records where
# the tire_size is 26.
short_rides.query('tire_size==26')
# Out:
#        duration  station_A_id  \
# 0            12            81
# 3             4            16
# 6            16            67
# 9             5            30
# 12            7             3
# ...         ...           ...
# 25750        15            16
# 25751        15            16
# 25755        11            15
# 25756        10            15
# 25757        14            15
#
#                                           station_A_name  station_B_id  \
# 0                                     Berry St at 4th St           323
# 3                                Steuart St at Market St            28
# 6      San Francisco Caltrain Station 2  (Townsend St...           107
# 9         San Francisco Caltrain (Townsend St at 4th St)            62
# 12          Powell St BART Station (Market St at 4th St)            27
# ...                                                  ...           ...
# 25750                            Steuart St at Market St           371
# 25751                            Steuart St at Market St           371
# 25755  San Francisco Ferry Building (Harry Bridges Pl...            34
# 25756  San Francisco Ferry Building (Harry Bridges Pl...            34
# 25757  San Francisco Ferry Building (Harry Bridges Pl...            42
#
#                                       station_B_name  bike_id  user_type  \
# 0                                 Broadway at Kearny     5480          2
# 3                       The Embarcadero at Bryant St     1883          1
# 6                              17th St at Dolores St     1035          2
# 9                        Victoria Manalo Draves Park      333          1
# 12                           Beale St at Harrison St     1863          3
# ...                                              ...      ...        ...
# 25750                     Lombard St at Columbus Ave     4372          2
# 25751                     Lombard St at Columbus Ave     5246          1
# 25755                 Father Alfred E Boeddeker Park     5063          1
# 25756                 Father Alfred E Boeddeker Park     5411          2
# 25757  San Francisco City Hall (Polk St at Grove St)     5157          2
#
#        user_birth_year user_gender  tire_size
# 0                 1959        Male         26
# 3                 1979        Male         26
# 6                 1981        Male         26
# 9                 1994        Male         26
# 12                1998        Male         26
# ...                ...         ...        ...
# 25750             1994        Male         26
# 25751             1995        Male         26
# 25755             2000        Male         26
# 25756             1998        Male         26
# 25757             1995        Male         26
#
# [12761 rows x 10 columns]

# %%
# Finally, produce a count of all records with FEMALE riders
# using the 26-inch wheeled rental bikes for their rentals of
# one hour or less.
female_riders = df[(df['user_gender'] == 'female'),(df['tire_size'] == 26),(df['duration'] == 1)].shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25755    False
# 25756    False
# 25757    False
# 25758    False
# 25759    False
# Name: user_gender, Length: 25760, dtype: bool, 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 25755     True
# 25756     True
# 25757     True
# 25758    False
# 25759    False
# Name: tire_size, Length: 25760, dtype: bool, 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25755    False
# 25756    False
# 25757    False
# 25758    False
# 25759    False
# Name: duration, Length: 25760, dtype: bool)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-43-e7b58f7f89c8> in <cell line: 4>()
#       2 # using the 26-inch wheeled rental bikes for their rentals of
#       3 # one hour or less.
# ----> 4 female_riders = df[(df['user_gender'] == 'female'),(df['tire_size'] == 26),(df['duration'] == 1)].shape()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3807                 #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808                 #  the TypeError.
# -> 3809                 self._check_indexing_error(key)
#    3810                 raise
#    3811
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _check_indexing_error(self, key)
#    5923             # if key is not a scalar, directly raise an error (the code below
#    5924             # would convert to numpy arrays and raise later any way) - GH29926
# -> 5925             raise InvalidIndexError(key)
#    5926
#    5927     @cache_readonly
#
# InvalidIndexError: (0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25755    False
# 25756    False
# 25757    False
# 25758    False
# 25759    False
# Name: user_gender, Length: 25760, dtype: bool, 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 25755     True
# 25756     True
# 25757     True
# 25758    False
# 25759    False
# Name: tire_size, Length: 25760, dtype: bool, 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25755    False
# 25756    False
# 25757    False
# 25758    False
# 25759    False
# Name: duration, Length: 25760, dtype: bool)
