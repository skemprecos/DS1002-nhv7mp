# %% [markdown]
# <a href="https://colab.research.google.com/github/skemprecos/DS1002-nhv7mp/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]
colors = 'c','g','r'

import matplotlib.pyplot as plt

fig, ax = plt.subplots()
patches, texts, pcts = ax.pie(
    slices, labels=labels, colors = colors, autopct='%.1f%%',
    wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
    textprops={'size': 'x-large'})
plt.setp(pcts, color='white', fontweight='bold')
ax.set_title("State Slices")
plt.tight_layout()

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)
a = [a for a in range(len(n))]
plt.hist(n, bins = 60)
plt.title("Histogram Data")
plt.show()

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x+b, color='green')
plt.scatter(x, y, marker = "^", color = 'c')
plt.title("Scatterplot")
plt.show()
