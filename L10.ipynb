# %% [markdown]
# <a href="https://colab.research.google.com/github/skemprecos/DS1002-nhv7mp/blob/main/L10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt   #a library

# %matplotlib inline

# %%
#importing the mockaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
mock_data.info
# Out:
# <bound method DataFrame.info of        id   first_name  last_name                        email  gender  age
# 0       1        Helli  Richardin    hrichardin0@homestead.com  Female   33
# 1       2     Eldridge    Tribble           etribble1@cnet.com    Male   76
# 2       3      Danella     Chelam              dchelam2@pen.io  Female   45
# 3       4       Melisa       Boyn              mboyn3@phoca.cz  Female    2
# 4       5        Tomas  McCarroll          tmccarroll4@mac.com    Male    9
# ..    ...          ...        ...                          ...     ...  ...
# 995   996       Connor     Scarse         cscarsern@github.com    Male   41
# 996   997  Constantino   Leadston           cleadstonro@w3.org    Male   52
# 997   998        Clair    Schulze          cschulzerp@dmoz.org    Male   50
# 998   999     Amabelle   Tampling           atamplingrq@hp.com  Female   69
# 999  1000       Joelle      Koche  jkocherr@simplemachines.org  Female   16
#
# [1000 rows x 6 columns]>

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
mock_data.head()
#the display is a default 5 records in pandas
# Out:
#    id first_name  last_name                      email  gender  age
# 0   1      Helli  Richardin  hrichardin0@homestead.com  Female   33
# 1   2   Eldridge    Tribble         etribble1@cnet.com    Male   76
# 2   3    Danella     Chelam            dchelam2@pen.io  Female   45
# 3   4     Melisa       Boyn            mboyn3@phoca.cz  Female    2
# 4   5      Tomas  McCarroll        tmccarroll4@mac.com    Male    9

# %%
mock_data.head(11)
# Out:
#     id  first_name  last_name                       email      gender  age
# 0    1       Helli  Richardin   hrichardin0@homestead.com      Female   33
# 1    2    Eldridge    Tribble          etribble1@cnet.com        Male   76
# 2    3     Danella     Chelam             dchelam2@pen.io      Female   45
# 3    4      Melisa       Boyn             mboyn3@phoca.cz      Female    2
# 4    5       Tomas  McCarroll         tmccarroll4@mac.com        Male    9
# 5    6       Toddy     Gellan    tgellan5@marketwatch.com        Male   61
# 6    7    Florinda     Juarez    fjuarez6@theatlantic.com      Female   14
# 7    8    Angelica    Aucoate        aaucoate7@discuz.net  Polygender   38
# 8    9       Danie    Ullyott         dullyott8@mysql.com        Male   64
# 9   10  Dianemarie    Doleman  ddoleman9@businessweek.com      Female   18
# 10  11     Germain      Noyes      gnoyesa@soundcloud.com        Male   11

# %%
mock_data.loc[0]
#asking for different items in our list ( n - 1)
# Out:
# id                                    1
# first_name                        Helli
# last_name                     Richardin
# email         hrichardin0@homestead.com
# gender                           Female
# age                                  33
# Name: 0, dtype: object

# %%
mock_data.describe()
#simple statistics
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    44.493000
# std     288.819436    25.857195
# min       1.000000     1.000000
# 25%     250.750000    21.000000
# 50%     500.500000    44.000000
# 75%     750.250000    66.000000
# max    1000.000000    90.000000

# %%
mock_data.columns
#get the columns from the data frame (headers)
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
mock_data = mock_data.rename(columns = {"first_name":"fname","last_name":"lname","email":"mail"})
mock_data.head(5)
# Out:
#    id     fname      lname                       mail  gender  age
# 0   1     Helli  Richardin  hrichardin0@homestead.com  Female   33
# 1   2  Eldridge    Tribble         etribble1@cnet.com    Male   76
# 2   3   Danella     Chelam            dchelam2@pen.io  Female   45
# 3   4    Melisa       Boyn            mboyn3@phoca.cz  Female    2
# 4   5     Tomas  McCarroll        tmccarroll4@mac.com    Male    9

# %%
mock_data['fname']
# Out:
# 0            Helli
# 1         Eldridge
# 2          Danella
# 3           Melisa
# 4            Tomas
#           ...
# 995         Connor
# 996    Constantino
# 997          Clair
# 998       Amabelle
# 999         Joelle
# Name: fname, Length: 1000, dtype: object

# %%
mock_data[['fname','lname']]
# Out:
#            fname      lname
# 0          Helli  Richardin
# 1       Eldridge    Tribble
# 2        Danella     Chelam
# 3         Melisa       Boyn
# 4          Tomas  McCarroll
# ..           ...        ...
# 995       Connor     Scarse
# 996  Constantino   Leadston
# 997        Clair    Schulze
# 998     Amabelle   Tampling
# 999       Joelle      Koche
#
# [1000 rows x 2 columns]

# %%
pd.value_counts(mock_data['gender']).plot.bar()
#function of pandas we are "grabbing"
# Out:
# <Axes: >

# %%
mock_data.groupby(['gender'])['age'].mean()
# Out:
# gender
# Agender        40.875000
# Bigender       39.600000
# Female         45.456376
# Genderfluid    40.588235
# Genderqueer    49.500000
# Male           43.632653
# Non-binary     43.541667
# Polygender     46.280000
# Name: age, dtype: float64
