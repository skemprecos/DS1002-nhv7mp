# %% [markdown]
# <a href="https://colab.research.google.com/github/skemprecos/DS1002-nhv7mp/blob/main/9_27_Pandas_df_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

la_df = pd.read_csv('la-crime-2020.csv')
la_df[:50]
la_df.loc[:50,["DATE OCC","Crm Cd Desc"]]
# Out:
#                   DATE OCC                                        Crm Cd Desc
# 0   01/08/2020 12:00:00 AM                           BATTERY - SIMPLE ASSAULT
# 1   01/01/2020 12:00:00 AM                           BATTERY - SIMPLE ASSAULT
# 2   02/13/2020 12:00:00 AM          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3   01/01/2020 12:00:00 AM           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4   01/01/2020 12:00:00 AM  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 5   01/01/2020 12:00:00 AM                                     RAPE, FORCIBLE
# 6   01/02/2020 12:00:00 AM           SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 7   01/04/2020 12:00:00 AM                          OTHER MISCELLANEOUS CRIME
# 8   01/04/2020 12:00:00 AM  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 9   05/26/2020 12:00:00 AM  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 10  01/04/2020 12:00:00 AM                              BURGLARY FROM VEHICLE
# ...
